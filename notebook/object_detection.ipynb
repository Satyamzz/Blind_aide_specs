# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/SEC_project-blind-aide
# Out:
# /content/drive/MyDrive/SEC_project-blind-aide

# %%
# !mv /content/drive/MyDrive/Colab-Notebooks/blind_aide.ipynb "/content/drive/MyDrive/SEC_project-blind-aide"
# Out:
# mv: cannot stat '/content/drive/MyDrive/Colab-Notebooks/blind_aide.ipynb': No such file or directory

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
#model = YOLO("yolo11n.yaml")  # build a new model from YAML
# model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
# model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights

# Train the model
#results = model.train(data="data.yaml", epochs=100, imgsz=640)

# %%
import os
location=os.getcwd()+'/classroom_objects'
print(location)
# Out:
# /content/drive/MyDrive/SEC_project-blind-aide/classroom_objects

# %%
# !yolo detect train model=yolo11m.pt data={location}/data.yaml epochs=50 imgsz=640 batch=8
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
