# %%
from ultralytics import YOLO

# %%
import cv2

# %%
# Load a model
model = YOLO("yolov8n.pt")  # you can use yolov8s.pt, yolov8m.pt, etc.
# Train on your custom dataset
results = model.train(data="D:\\Blind_aide_glasses\\Blind_aide_specs\\objects_classroom\\data.yaml",
                      epochs=100,
                      imgsz=640)
# model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
# model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights
# Train the model
# results = model.train(data="coco8.yaml", epochs=100, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.221 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.204  Python-3.11.9 torch-2.8.0+cpu CPU (12th Gen Intel Core i5-12450H)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:\Blind_aide_glasses\Blind_aide_specs\objects_classroom\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\Blind_aide_glasses\Blind_aide_specs\notebook\runs\detect\train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\trainer.py:634, in BaseTrainer.get_dataset(self)
#     628 elif self.args.data.rsplit(".", 1)[-1] in {"yaml", "yml"} or self.args.task in {
#     629     "detect",
#     630     "segment",
#     631     "pose",
#     632     "obb",
#     633 }:
# --> 634     data = check_det_dataset(self.args.data)
#     635     if "yaml_file" in data:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\data\utils.py:467, in check_det_dataset(dataset, autodownload)
#     466     m += f"\nNote dataset download directory is '{DATASETS_DIR}'. You can update this in '{SETTINGS_FILE}'"
# --> 467     raise FileNotFoundError(m)
#     468 t = time.time()
#
# FileNotFoundError: Dataset 'D://Blind_aide_glasses/Blind_aide_specs/objects_classroom/data.yaml' images not found, missing path 'C:\content\yolo_20\data\images\val'
# Note dataset download directory is 'C:\Users\satya\datasets'. You can update this in 'C:\Users\satya\AppData\Roaming\Ultralytics\settings.json'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 4
#       2 model = YOLO("yolov8n.pt")  # you can use yolov8s.pt, yolov8m.pt, etc.
#       3 # Train on your custom dataset
# ----> 4 results = model.train(data="D:\\Blind_aide_glasses\\Blind_aide_specs\\objects_classroom\\data.yaml",
#       5                       epochs=100,
#       6                       imgsz=640)  # build a new model from YAML
#       7 # model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
#       8 # model = YOLO("yolo11n.yaml").load("yolo11n.pt")  # build from YAML and transfer weights
#       9 # Train the model
#      10 # results = model.train(data="coco8.yaml", epochs=100, imgsz=640)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py:795, in Model.train(self, trainer, **kwargs)
#     792 if args.get("resume"):
#     793     args["resume"] = self.ckpt_path
# --> 795 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     796 if not args.get("resume"):  # manually set model only if not resuming
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\models\yolo\detect\train.py:65, in DetectionTrainer.__init__(self, cfg, overrides, _callbacks)
#      56 def __init__(self, cfg=DEFAULT_CFG, overrides: dict[str, Any] | None = None, _callbacks=None):
#      57     """
#      58     Initialize a DetectionTrainer object for training YOLO object detection model training.
#      59
#    (...)     63         _callbacks (list, optional): List of callback functions to be executed during training.
#      64     """
# ---> 65     super().__init__(cfg, overrides, _callbacks)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\trainer.py:158, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     156 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     157 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 158     self.data = self.get_dataset()
#     160 self.ema = None
#     162 # Optimization utils init
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\trainer.py:638, in BaseTrainer.get_dataset(self)
#     636             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     637 except Exception as e:
# --> 638     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     639 if self.args.single_cls:
#     640     LOGGER.info("Overriding class names with single class.")
#
# RuntimeError: Dataset 'D://Blind_aide_glasses/Blind_aide_specs/objects_classroom/data.yaml' error  Dataset 'D://Blind_aide_glasses/Blind_aide_specs/objects_classroom/data.yaml' images not found, missing path 'C:\content\yolo_20\data\images\val'
# Note dataset download directory is 'C:\Users\satya\datasets'. You can update this in 'C:\Users\satya\AppData\Roaming\Ultralytics\settings.json'

# %%
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics 8.3.204  Python-3.11.9 torch-2.8.0+cpu CPU (12th Gen Intel Core i5-12450H)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access  (ping: 0.40.1 ms, read: 92.972.5 MB/s, size: 54.0 KB)
# val: Scanning C:\Users\satya\datasets\coco8\labels\val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 3.8Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all          4         17      0.705      0.746      0.912      0.652
#                 person          3         10      0.764       0.65      0.666       0.33
#                    dog          1          1      0.532          1      0.995      0.796
#                  horse          1          2      0.722          1      0.995      0.676
#               elephant          1          2      0.608      0.825      0.828      0.322
#               umbrella          1          1      0.604          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 3.0ms preprocess, 201.8ms inference, 0.0ms loss, 6.1ms postprocess per image
# Results saved to C:\Users\satya\runs\detect\train32
# array([    0.32955,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,       0.796,     0.67575,     0.65245,     0.65245,     0.32238,     0.65245,     0.65245,     0.65245,
#            0.65245,      0.8955,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,
#            0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,      0.8955,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,
#            0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245,     0.65245])

# %%
from IPython.display import display, Image, clear_output

# Run webcam loop in Jupyter
for result in model.predict(source=0, stream=True, conf=0.5):
    frame = result.plot()  # annotated frame
    clear_output(wait=True)
    display(Image(data=cv2.imencode(".jpg", frame)[1].tobytes()))

# %%
model.save("object_blind_aide.pt")

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml') 

# capture frames from a camera
cap = cv2.VideoCapture(0)

# loop runs if capturing has been initialized.
while 1: 

    # reads frames from a camera
    ret, img = cap.read() 

    # convert to gray scale of each frames
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detects faces of different sizes in the input image
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x,y,w,h) in faces:
        # To draw a rectangle in a face 
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,0),2) 
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]

        # Detects eyes of different sizes in the input image
        eyes = eye_cascade.detectMultiScale(roi_gray) 

        #To draw a rectangle in eyes
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,127,255),2)

    # Display an image in a window
    cv2.imshow('img',img)

    # Wait for Esc key to stop
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break

# Close the window
cap.release()

# De-allocate any associated memory usage
cv2.destroyAllWindows()
